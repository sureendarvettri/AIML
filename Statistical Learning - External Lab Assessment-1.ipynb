# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('Laliga.csv', header = 0, skiprows=1)

# %%
df
# Out:
#     Pos              Team  Seasons Points GamesPlayed GamesWon GamesDrawn  \
# 0     1       Real Madrid       86   4385        2762     1647        552
# 1     2         Barcelona       86   4262        2762     1581        573
# 2     3   Atletico Madrid       80   3442        2614     1241        598
# 3     4          Valencia       82   3386        2664     1187        616
# 4     5   Athletic Bilbao       86   3368        2762     1209        633
# ..  ...               ...      ...    ...         ...      ...        ...
# 56   57             Xerez        1     34          38        8         10
# 57   58            Condal        1     22          30        7          8
# 58   59   Atletico Tetuan        1     19          30        7          5
# 59   60  Cultural Leonesa        1     14          30        5          4
# 60   61            Girona        1      -           -        -          -
#
#    GamesLost GoalsFor GoalsAgainst Champion Runner-up Third Fourth Fifth  \
# ...

# %%
#Replace Dash with 0

# %%
#Question 1:
df.replace('-', 0, inplace=True)

# %%
df
# Out:
#     Pos              Team  Seasons Points GamesPlayed GamesWon GamesDrawn  \
# 0     1       Real Madrid       86   4385        2762     1647        552
# 1     2         Barcelona       86   4262        2762     1581        573
# 2     3   Atletico Madrid       80   3442        2614     1241        598
# 3     4          Valencia       82   3386        2664     1187        616
# 4     5   Athletic Bilbao       86   3368        2762     1209        633
# ..  ...               ...      ...    ...         ...      ...        ...
# 56   57             Xerez        1     34          38        8         10
# 57   58            Condal        1     22          30        7          8
# 58   59   Atletico Tetuan        1     19          30        7          5
# 59   60  Cultural Leonesa        1     14          30        5          4
# 60   61            Girona        1      0           0        0          0
#
#    GamesLost GoalsFor GoalsAgainst Champion Runner-up Third Fourth Fifth  \
# ...

# %%
#Question 2:
#Print all the teams which have started playing between 1930-1980

# %%
#Solution::1
for i in range(len(df)):
    if(pd.to_numeric(df.loc[i,'Debut'].split('-'))[0] >= 1930 and pd.to_numeric(df.loc[i,'Debut'].split('-'))[0] <= 1980):
        print(df.loc[i,'Team'])
# Out:
# Valencia
# Sevilla
# Zaragoza
# Real Betis
# Deportivo La Coruna
# Celta Vigo
# Valladolid
# Sporting Gijon
# Osasuna
# Malaga
# Oviedo
# Mallorca
# Las Palmas
# Granada
# Rayo Vallecano
# Elche
# Hercules
# Tenerife
# Murcia
# Alaves
# Levante
# Salamanca
# Sabadell
# Cadiz
# Castellon
# Cordoba
# Recreativo
# Burgos CF
# Pontevedra
# Gimnastic
# Alcoyano
# Jaen
# AD Almeria
# Lleida
# Condal
# Atletico Tetuan
# Cultural Leonesa

# %%
#Solution 2

df_after30 = df.loc[df["Debut"] >="1930",:]
df_after30_before80 = df_after30.loc[df_after30["Debut"]<="1980",:]
df_after30_before80
# Out:
#     Pos                 Team  Seasons Points GamesPlayed GamesWon GamesDrawn  \
# 3     4             Valencia       82   3386        2664     1187        616
# 5     6              Sevilla       73   2819        2408      990        531
# 8     9             Zaragoza       58   2109        1986      698        522
# 9    10           Real Betis       51   1884        1728      606        440
# 10   11  Deportivo La Coruna       45   1814        1530      563        392
# 11   12           Celta Vigo       51   1789        1698      586        389
# 12   13           Valladolid       42   1471        1466      463        384
# 14   15       Sporting Gijon       43   1389        1458      471        358
# 15   16              Osasuna       37   1351        1318      426        327
# 16   17               Malaga       36   1314        1255      390        330
# 17   18               Oviedo       38   1174        1192      408        292
# ...

# %%
#Question 3:
#Print the list of teams which came Top 5 in terms of points

# %%
df['Points'] = df.Points.astype('int')
df.sort_values(by = 'Points', ascending=False).head(5)
# Out:
#    Pos             Team  Seasons  Points GamesPlayed GamesWon GamesDrawn  \
# 0    1      Real Madrid       86    4385        2762     1647        552
# 1    2        Barcelona       86    4262        2762     1581        573
# 2    3  Atletico Madrid       80    3442        2614     1241        598
# 3    4         Valencia       82    3386        2664     1187        616
# 4    5  Athletic Bilbao       86    3368        2762     1209        633
#
#   GamesLost GoalsFor GoalsAgainst Champion Runner-up Third Fourth Fifth Sixth  \
# 0       563     5947         3140       33        23     8      8     3     4
# 1       608     5900         3114       25        25    12     12     4     6
# 2       775     4534         3309       10         8    16      9     7     6
# 3       861     4398         3469        6         6    10     11    10     7
# 4       920     4631         3700        8         7    10      5     8    10
#
#     T    Debut Since/LastApp  BestPosition
# ...

# %%
#Question 4: 
#Write a function with name “Goal_diff_count” which should return all the teams with their
#Goal Differences. Using the same function, find the team which has maximum and
#minimum goal difference. (5 points)
#Goal_diff_count = GoalsFor - GoalsAgainst

# %%
def goal_diff_count(dfs):    
    dfs['Goal Difference'] = 0
    df['GoalsFor'] = df.GoalsFor.astype('int')
    df['GoalsAgainst'] = df.GoalsAgainst.astype('int')
    for i in range(len(df)):
        dfs.loc[i,'Goal Difference'] = dfs.loc[i,'GoalsFor']-dfs.loc[i,'GoalsAgainst']
    return dfs

# %%
df = goal_diff_count(df)

goalDiff_df = df.sort_values(by=['Goal Difference'],ascending= True)
print("Team with min goal difference:\n",goalDiff_df.head(1))
print("Team with max goal difference:\n",goalDiff_df.tail(1))
# Out:
# Team with min goal difference:
#      Pos              Team  Seasons  Points GamesPlayed GamesWon GamesDrawn  \
# 13   14  Racing Santander       44    1416        1428      453        336
#
#    GamesLost  GoalsFor  GoalsAgainst  ... Runner-up Third Fourth Fifth Sixth  \
# 13       639      1843          2368  ...         1     1      2     0     1
#
#     T Debut Since/LastApp BestPosition  Goal Difference
# 13  5  1929       2011-12            2             -525
#
# [1 rows x 21 columns]
# Team with max goal difference:
#     Pos         Team  Seasons  Points GamesPlayed GamesWon GamesDrawn  \
# 0    1  Real Madrid       86    4385        2762     1647        552
#
#   GamesLost  GoalsFor  GoalsAgainst  ... Runner-up Third Fourth Fifth Sixth  \
# 0       563      5947          3140  ...        23     8      8     3     4
#
#     T Debut Since/LastApp BestPosition  Goal Difference
# 0  79  1929          1929            1             2807
#
# [1 rows x 21 columns]

# %%
#Question5:
#Create a new column with the name “Winning Percent” and append it to the data set (5points)
#Percentage of Winning = (GamesWon / GamesPlayed)*100

df['GamesWon'] = df.GamesWon.astype('int')
df['GamesPlayed'] = df.GamesPlayed.astype('int')

df['Winning Percent'] = (df['GamesWon']/df['GamesPlayed'])*100
df.sort_values(by = 'Winning Percent', ascending=False).head(5)
# Out:
#    Pos             Team  Seasons  Points  GamesPlayed  GamesWon GamesDrawn  \
# 0    1      Real Madrid       86    4385         2762      1647        552
# 1    2        Barcelona       86    4262         2762      1581        573
# 2    3  Atletico Madrid       80    3442         2614      1241        598
# 3    4         Valencia       82    3386         2664      1187        616
# 4    5  Athletic Bilbao       86    3368         2762      1209        633
#
#   GamesLost  GoalsFor  GoalsAgainst  ... Third Fourth Fifth Sixth   T  \
# 0       563      5947          3140  ...     8      8     3     4  79
# 1       608      5900          3114  ...    12     12     4     6  83
# 2       775      4534          3309  ...    16      9     7     6  56
# 3       861      4398          3469  ...    10     11    10     7  50
# 4       920      4631          3700  ...    10      5     8    10  49
#
#      Debut Since/LastApp BestPosition Goal Difference  Winning Percent
# ...

# %%
#Group teams based on their “Best position” and print the sum of their points for all
#positions (7.5 points)

# %%
df.groupby("BestPosition").Points.sum()
# Out:
# BestPosition
# 1     27933
# 2      6904
# 3      5221
# 4      6563
# 5      1884
# 6      2113
# 7      1186
# 8      1134
# 9        96
# 10      450
# 11      445
# 12      511
# 14       71
# 15       14
# 16       81
# 17      266
# 19       81
# 20       34
# Name: Points, dtype: int32
